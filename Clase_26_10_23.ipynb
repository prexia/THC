# %% [markdown]
# <a href="https://colab.research.google.com/github/prexia/THC/blob/desarollo/Clase_26_10_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
xpoints=np.array([0,6]) #Definimos un punto
ypoints=np.array([0,250]) #Definimos otro punto

plt.plot(xpoints,ypoints) #Los mostramos en un grafica
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
xpoints=np.array([1,8]) #Definimos un punto
ypoints=np.array([3,10]) #Definimos otro punto

plt.plot(xpoints,ypoints) #Los mostramos en un grafica
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
xpoints=np.array([1,8]) #Definimos un punto
ypoints=np.array([3,10]) #Definimos otro punto

plt.plot(xpoints,ypoints,"o") #Ponemos entre comillas una o para que nos de solo los puntos
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
xpoints=np.array([0,250,1,2,6,8]) #Definimos un punto
ypoints=np.array([1,8,3,8,1,10]) #Definimos otro punto

plt.plot(xpoints,ypoints,"o") #Ponemos entre comillas una o para que nos de solo los puntos
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,marker="o") #Ponemos un marker para unir los puntos
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,marker="*") #Ponemos un asterisco para que sean estrellas los puntos
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,marker="D")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,"s:r") #No le ponemos marker. el r es el color y el dos puntos la linea punteada
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,"s--g") #No le ponemos marker. el r es el color y el dos puntos la linea punteada
plt.show #El orden de sintaxis es forma del punto,tipo de linea y color
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,marker="D",ms= 20) #Ponemos marker, tipo de punto, y con el ms es el tamaño del ´punto
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,"*--m",ms= 20) #Si  el marker tambien se puede tipo de punto, y con el ms es el tamaño del ´punto
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,"s--g",ms= 20,mec="r") #mec= al color del controno del punto
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,linestyle="dotted") #Sin puntos, pura linea con su estilo, ls=linestyle
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt # Importar biblioteca matplotlib
import numpy as np #Importar biblioteca numpy
ypoints=np.array([3,8,1,10]) #Definimos otro punto

plt.plot(ypoints,linewidth =20) #linewidth= grosor de la linea
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([2,5,7,9])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(list(range(1,101)))
y = np.array(list(range(200,300)))

plt.plot(x,y)

plt.xlabel("Nombre del eje x ")
plt.ylabel("Nombre del eje y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(list(range(1,101)))
y = np.array(list(range(200,300)))

plt.plot(x,y)
plt.title("Nombre de la grafica") #.title para nombre de la grafica
plt.xlabel("Nombre del eje x ") #.xlabel para nombre del eje x
plt.ylabel("Nombre del eje y") #y.lable par anombre del eje y
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(list(range(1,101)))
y = np.array(list(range(200,300)))

plt.plot(x,y)
plt.title("Nombre de la grafica") #.title para nombre de la grafica
plt.xlabel("Nombre del eje x ") #.xlabel para nombre del eje x
plt.ylabel("Nombre del eje y") #y.lable par anombre del eje y
plt.grid() #Para poner cuadricula
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(list(range(1,101)))
y = np.array(list(range(200,300)))

plt.plot(x,y)
plt.title("Nombre de la grafica") #.title para nombre de la grafica
plt.xlabel("Nombre del eje x ") #.xlabel para nombre del eje x
plt.ylabel("Nombre del eje y") #y.lable par anombre del eje y
plt.grid(axis ="x") #Para poner cuadricula solo en un eje ponemos axis
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(list(range(1,101)))
y = np.array(list(range(200,300)))

plt.plot(x,y)
plt.title("Nombre de la grafica") #.title para nombre de la grafica
plt.xlabel("Nombre del eje x ") #.xlabel para nombre del eje x
plt.ylabel("Nombre del eje y") #y.lable par anombre del eje y
plt.grid(color="green",linestyle="--",linewidth=2)
plt.show()

# %%
import numpy as np
import math
multiplos_de_pi =np.array([0,6*np.pi,np.pi])

x=np.linspace(0,6*np.pi,300)
y=np.array(np.sin(x))
z=np.array(np.cos(x))
plt.plot(x,y,x,z)
plt.title("Grafica de seno y coseno") #.title para nombre de la grafica
plt.xlabel("eje x ") #.xlabel para nombre del eje x
plt.ylabel(" eje y")
plt.grid(color="green",linestyle="--",linewidth=0.4)
plt.plot(x,y,"--b",ms= 4,mec="r")
plt.plot(x,z,"--g",ms= 4,mec="r")

# %%
def graficacion(x):
  multiplos_de_pi =np.array([0,6*np.pi,np.pi])

  x=np.linspace(0,6*np.pi,300)
  y=np.array(np.sin(x))
  z=np.array(np.cos(x))
  plt.plot(x,y,x,z,"D--k",)
  plt.grid(color="pink",lw=2)

  return(plt.plot(x,y,x,z))
graficacion(5)
