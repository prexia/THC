# %% [markdown]
# <a href="https://colab.research.google.com/github/prexia/THC/blob/desarollo/Clase_12_08_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type((1,2))
# Out:
# tuple

# %%
#** exponencial
#%
#// division entera
#/ division
#+suma
#-resta
#OPERACIO0NES NO ITERABLES""

# %%
x = (1,2)
x[0]
#
# Out:
# 1

# %%
x = (1,2)
x[1]
#
# Out:
# 2

# %%
#Tupla
x= (9,5,4,3,6) #La tupla lleva corchertes y no se puede modificar su estructura de la tupla como a las listas
x[0]
# Out:
# 9

# %%
#Lista
l = [1,4,56,8,3] #La lista lleva corchetes
print(l)
# Out:
# [1, 4, 56, 8, 3]

# %%
l[-1] # Con el -1 podemos ver el ultimo elemento de la lista y con el -2 el penultimo y asi consecutivamente
# Out:
# 3

# %%
len(l) #Cantidad de elementos de una lista
# Out:
# 5

# %%
l.append(42) #Agrega un elemento a la lista copn el punto append
print(l)
# Out:
# [1, 4, 56, 8, 3, 42]

# %%
y="124",12
print=(type(y))

# %%
cadena ="Hola Mundo !0"
print(cadena)
# Out:
# ('H', 'o', 'l', 'a', ' ', 'M', 'u', 'n', 'd', 'o', ' ', '!', '0')

# %%
cadena = "Hola Mundo!0"
print(cadena[1:4]) #Toma de los elementos 1 hasta el 4 de la cadena
# Out:
# ('o', 'l', 'a')

# %%
diccionario = {"llave":"valor","hola":"mundo"}
diccionario["llave"]
diccionario["hola"]
# Out:
# 'mundo'
