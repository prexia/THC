# %% [markdown]
# <a href="https://colab.research.google.com/github/prexia/THC/blob/desarollo/Clase07_11_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code='?raw=true'
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)#sep:separador por coma, idex_col 1 es para que la columna 1 se cambie

# %%
df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.shape
# Out:
# (2484, 3)

# %%
df.info() #Contenido del archivo de y cuanto pesa
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2014-08-29 to 2016-03-23
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   float64
#  2   No. of confirmed deaths  1648 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 77.6+ KB

# %%
df.head() #Parte arriba de la tabla
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29        Guinea                   482.0                    287.0
# 2014-08-29       Nigeria                    15.0                      6.0
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-08-29       Liberia                   322.0                    225.0
# 2014-09-05        Guinea                   604.0                    362.0

# %%
df.tail() #Parte de abajo de la tabla
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0

# %%
df.isnull()
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-09-05    False                   False                    False
# ...             ...                     ...                      ...
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
#
# [2484 rows x 3 columns]

# %%
df.isnull().sum() #La suma de todos lo datos isnull
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# dtype: int64

# %%
df['Country'].isin(['Mexico']).sum() #Mexico no esta
# Out:
# 0

# %%
SL=df[df['Country']=='Sierra Leone']

# %%
SL
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-09-05  Sierra Leone                  1146.0                    443.0
# 2014-09-08  Sierra Leone                  1234.0                    461.0
# 2014-09-12  Sierra Leone                  1287.0                    478.0
# 2014-09-16  Sierra Leone                  1464.0                    514.0
# ...                  ...                     ...                      ...
# 2015-12-17  Sierra Leone                  8704.0                   3589.0
# 2015-12-22  Sierra Leone                  8704.0                   3589.0
# 2015-12-23  Sierra Leone                  8704.0                   3589.0
# 2015-12-29  Sierra Leone                  8704.0                   3589.0
# 2016-03-23  Sierra Leone                  8704.0                   3589.0
#
# [259 rows x 3 columns]

# %%
SL.head()
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-09-05  Sierra Leone                  1146.0                    443.0
# 2014-09-08  Sierra Leone                  1234.0                    461.0
# 2014-09-12  Sierra Leone                  1287.0                    478.0
# 2014-09-16  Sierra Leone                  1464.0                    514.0

# %%
SL=SL.drop('Country',axis=1) #Borra una columna en este caso country axis 1 para que borre columna y no renglon

# %%
SL
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                   935.0                    380.0
# 2014-09-05                  1146.0                    443.0
# 2014-09-08                  1234.0                    461.0
# 2014-09-12                  1287.0                    478.0
# 2014-09-16                  1464.0                    514.0
# ...                            ...                      ...
# 2015-12-17                  8704.0                   3589.0
# 2015-12-22                  8704.0                   3589.0
# 2015-12-23                  8704.0                   3589.0
# 2015-12-29                  8704.0                   3589.0
# 2016-03-23                  8704.0                   3589.0
#
# [259 rows x 2 columns]

# %%
SL.fillna(0.0,inplace=True)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    2
# dtype: int64

# %%
SL['No. of confirmed deaths'].mean()
# Out:
# 3081.019305019305

# %%
SL['No. of confirmed cases'].mean()
# Out:
# 7883.671814671815

# %%
Dates=SL.index[0:-1:10]
NCC=SL['No. of confirmed cases'][0:-1:10]
NCD=SL['No. of confirmed deaths'][0:-1:10]

# %%
NCC
# Out:
# Date
# 2014-08-29     935.0
# 2014-10-03    2179.0
# 2014-11-07    4149.0
# 2014-12-17    6702.0
# 2015-01-06    7602.0
# 2015-01-20    7903.0
# 2015-02-03    8059.0
# 2015-02-18    8212.0
# 2015-03-06    8389.0
# 2015-03-24    8520.0
# 2015-04-17    8569.0
# 2015-05-04    8592.0
# 2015-05-18    8603.0
# 2015-06-01    8618.0
# 2015-06-15    8649.0
# 2015-06-29    8664.0
# 2015-07-13    8687.0
# 2015-07-27    8694.0
# 2015-08-10    8697.0
# 2015-08-24    8697.0
# 2015-09-07    8699.0
# 2015-09-21    8704.0
# 2015-10-05    8704.0
# 2015-10-23    8704.0
# 2015-11-12    8704.0
# 2015-12-10    8704.0
# Name: No. of confirmed cases, dtype: float64

# %%
NCD
# Out:
# Date
# 2014-08-29     380.0
# 2014-10-03     575.0
# 2014-11-07     921.0
# 2014-12-17    1876.0
# 2015-01-06    2577.0
# 2015-01-20    2779.0
# 2015-02-03    2910.0
# 2015-02-18    3042.0
# 2015-03-06    3210.0
# 2015-03-24    3381.0
# 2015-04-17    3499.0
# 2015-05-04    3536.0
# 2015-05-18    3540.0
# 2015-06-01    3545.0
# 2015-06-15    3553.0
# 2015-06-29    3566.0
# 2015-07-13    3580.0
# 2015-07-27    3585.0
# 2015-08-10    3585.0
# 2015-08-24    3586.0
# 2015-09-07    3587.0
# 2015-09-21    3589.0
# 2015-10-05    3589.0
# 2015-10-23    3589.0
# 2015-11-12    3589.0
# 2015-12-10    3589.0
# Name: No. of confirmed deaths, dtype: float64

# %%
plt.plot(Dates,NCC,'o--k',label='Infectados')
plt.plot(Dates,NCD,'D--b',label='Decesos')
plt.grid()
plt.title('Avance del ebola en Sierrra Leona ')
plt.ylabel('Casos confirmados')
plt.xlabel('Periodod de Tiempo')
plt.xticks(rotation=90,fontsize=9)
plt.legend()
plt.show()

# %%
PIvsD=100*SL['No. of confirmed deaths']/SL['No. of confirmed cases']
SL['PIvsD']=PIvsD

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290

# %%
recuperados=(100-PIvsD/100)*SL['No. of confirmed cases']
SL['recuperados']=recuperados

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD  \
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290
#
#             recuperados
# Date
# 2014-08-29      93120.0
# 2014-09-05     114157.0
# 2014-09-08     122939.0
# 2014-09-12     128222.0
# 2014-09-16     145886.0
