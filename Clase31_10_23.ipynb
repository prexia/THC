# %% [markdown]
# <a href="https://colab.research.google.com/github/prexia/THC/blob/desarollo/Clase31_10_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
#Plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2) #una fila, so columnas y grafica la primer
plt.plot(x,y)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2) #Dos renglones y una columna
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1) #Dos renglones tres columnas y trabaja en el eespacio 1
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2) #Dos renglones tres columas y trabaja en le espacio 2
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)#Dos renglones tres columas y trabaja en le espacio 3
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)#Dos renglones tres columas y trabaja en le espacio 4
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)#Dos renglones tres columas y trabaja en le espacio 5
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)#Dos renglones tres columas y trabaja en le espacio 6
plt.plot(x,y)
#Trabaja primero hacia los lados y luego hacia abajo primero se acaba el rengln antes de pasar al siguiente
 #Al ser solo 6 espacios ya que tenemos 3x2 solo llegas hasta el 6
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Salidas") #Titulo para cada una de las graficas

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Entradas") #plt.title

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Holaaa")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Adios")

plt.suptitle("Bienvenida") #Titulo grande para todas las graficas plt.suptitle

plt.show()

# %%
multiplos_de_pi =np.array([0,2*np.pi,100])

x=np.linspace(0,6*np.pi,300)
y=np.array(np.sin(x))
z=np.array(np.cos(x))
plt.suptitle("Graficas trigonometricas")
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Grafica de seno")
plt.grid(color="green",linestyle="--",linewidth=0.5)
plt.plot(x,y,"--b",ms= 5,mec="r")
plt.subplot(1,2,2)
plt.plot(x,z)
plt.title("Grafica de coseno")
plt.grid(color="red",linestyle="-",linewidth=0.5)
plt.plot(x,z,"--g",ms= 5,mec="r")

# %%
def graficacion(x):
  multiplos_de_pi =np.array([0,6*np.pi,np.pi])

  x=np.linspace(0,6*np.pi,300)
  y=np.array(np.sin(x))
  z=np.array(np.cos(x))
  plt.suptitle("Graficas trigonometricas")
  plt.subplot(1,2,1)
  plt.plot(x,y)
  plt.title("Grafica de seno")
  plt.grid(color="green",linestyle="--",linewidth=0.5)
  plt.plot(x,y,"--b",ms= 5,mec="r")
  plt.subplot(1,2,2)
  plt.plot(x,z)
  plt.title("Grafica de coseno")
  plt.grid(color="red",linestyle="-",linewidth=0.5)


  return(plt.plot(x,y,x,z))
graficacion(5)

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.bar(x,y) #plt.bar para graficar barras en vez de rectas
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.bar(x,y)#plt.bar para graficar barras en vez de rectas
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
por=([10,20,70])
clases=(["A","B","C"])
plt.pie(por,labels=clases,autopct="x0.1f%%")

plt.show()
